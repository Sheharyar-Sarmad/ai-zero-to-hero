# %%
def get_hash(key):
    h = 0
    for char in key:
        h += ord(char)
    return h % 100
print(get_hash("march 10"))
# Out:
# 52

# %%
# class HashTable:
#     def __init__(self):
#         self.MAX = 100
#         self.arr = [None for i in range(self.MAX)]

#     def get_hash(self , key):
#         h = 0
#         for char in key:
#             h += ord(char)
#         return h % self.MAX

#     def __setitem__(self , key , val):
#         h = self.get_hash(key)
#         self.arr[h] = val

#     def __getitem__(self , key): 
#         h = self.get_hash(key)
#         return self.arr[h]
        
#     def __delitem__(self , key): 
#         h = get_hash(key)
#         self.arr[h] = None

# %%
# t = HashTable()
# t['march 6'] = 130
# t['march 1'] = 20
# t['dec 17'] = 20

# %%
# del t['march 6']

# %%
class HashTable:
    def __init__(self):
        max_elem = 100
        data = [None for i in range(self.max_elem)]

    def get_hash(self , key): 
        h = 0
        for characters in h:
            h += ord(characters) # or h = h + ord(characters)
        return h % self.max_elem

    def __setitem__(self , key , value): # lets dive with real values: (self , 'march 6' , 120)
        h = self.get_hash(key) # self.get_hash('march 6') , O(1) , this will return the hash value as 9
        self.data[h] = value # self.data[9] = 120 , O(1) , this means at nine index(indeces) set value as 120

    def __getvalue__(self , key): # lets dive with real values: (self , 'march 6' )
        h = self.get_hash(key)  # self.get_hash('march 6') , O(1) , this will return the hash value as 9
        return self.data[h] # this will return the function as self.data[9] means get the 9th index value

    def __delitem__(self , key)
