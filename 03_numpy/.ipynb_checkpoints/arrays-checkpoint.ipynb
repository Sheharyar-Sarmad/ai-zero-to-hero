# %%
print("hello world")
# Out:
# hello world

# %%
a = 12
b = 13.3

if a % 2 == 0 and isinstance(b , float) :
    print("numpy to run horhi hai laadle")
else :
    print("numpy nhi run horhi hai")

def hello() :
    print("Hello aoa kese hai laadle")

hello()
# Out:
# numpy to run horhi hai laadle
# Hello aoa kese hai laadle

# %%
print()
