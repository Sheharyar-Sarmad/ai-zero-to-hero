# %%
# Pandas :

# Pandas is a Python library used to store, analyze, clean, and manipulate structured data efficiently.

# handling datasets
# cleaning missing values
# filtering data  
# analyzing statistics 
# preparing data for machine learning 

# Almost every AI engineer and data scientist uses Pandas daily. 

# Quote: 

# "In the world of data science, mastering pandas is like learning to read before writing poetry"

# %%
# Origin story of pandas: 

# Pandas is created by Wes Mckiney in 2008 to solve a problem he wanted to create a library of python which is fast , flexible and easy to use 
# He realized that in python the data management of complex rapidly is missing and he started to create pandas who's main focus is data cleaning , 
# data ananlyse and data manipulation

# %%
# Use case of pandas: 

# Data cleaning 
# Data analysis 
# Data transformation 
# Data visualization(basic level) 
# Data aggregation 
# File Handling 
# Data Filtering & Selection 
# Time series analysis

# %%
# What we are going to learn in pandas:

# Index of learning : 

# Series 
# Data Frames 
# Missing data 
# Merging , joing and concatenation  
# GroupBy & Aggregation 
# 
# 
# 
#
